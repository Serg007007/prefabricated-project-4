# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Сергей! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект.
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# # Проект: "Поиск по изображениям"
#
# Пользователи размещают свои фотографии на хостинге и сопровождают их полным описанием: указывают место съёмок, модель камеры и т. д. Отличительная особенность сервиса — описание: его может предоставить не только тот, кто размещает фотографию, но и другие пользователи портала.
#
# ## Цель:
#
# Разработка поиска референсных фотографий для фотографов. Суть поиска заключается в следующем: пользователь сервиса вводит описание нужной сцены. Сервис выводит несколько фотографий с такой же или похожей сценой.
#
# Для демонстрационной версии нужно выбрать лучшую модель, которая получит векторное представление изображения, векторное представление текста, а на выходе выдаст число от 0 до 1 — и покажет, насколько текст и картинка подходят друг другу.
#
# ## Юридические ограничения
#
# В некоторых странах, где работает компания, действуют ограничения по обработке изображений: поисковым сервисам и сервисам, предоставляющим возможность поиска, запрещено без разрешения родителей или законных представителей предоставлять любую информацию, в том числе, но не исключительно, текстов, изображений, видео и аудио, содержащие описание, изображение или запись голоса детей. Ребёнком считается любой человек, не достигший 16-ти лет.

# %% [markdown]
# ### Описание данных
#
# Данные лежат в папке `/datasets/image_search/`.
#
# В файле `train_dataset.csv` находится информация, необходимая для обучения: имя файла изображения, идентификатор описания и текст описания. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `train_images` содержатся изображения для тренировки модели.
#
# В файле `CrowdAnnotations.tsv` — данные по соответствию изображения и описания, полученные с помощью краудсорсинга. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
# 3. Доля людей, подтвердивших, что описание соответствует изображению.
# 4. Количество человек, подтвердивших, что описание соответствует изображению.
# 5. Количество человек, подтвердивших, что описание не соответствует изображению.
#
# В файле `ExpertAnnotations.tsv` содержатся данные по соответствию изображения и описания, полученные в результате опроса экспертов. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
#
# 3, 4, 5 — оценки трёх экспертов.
#
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью.
#
# В файле `test_queries.csv` находится информация, необходимая для тестирования: идентификатор запроса, текст запроса и релевантное изображение. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `test_images` содержатся изображения для тестирования модели.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Просьба: </b> Для меня данный проект оказался самым тяжёлым на всем курсе обучения. Потратил очень много времени и сил на его выполнение, но так и не получилось сделать до конца. Прошу помочь с обучением нейронной сети. Я зашел в тупик и не знаю что с ней не так и почему она так плохо обучается и предсказывает оценки.
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера </b>
#
# ОК, постараюсь дать уместные советы. Проект на самом деле не простой.</div>

# %%
import nltk
import numpy as np
import pandas as pd
import tensorflow as tf
import torch
pd.set_option('display.float_format', '{:,.2f}'.format) # убираем экспонентациальные формы
import warnings
warnings.simplefilter('ignore')
pd.set_option('display.max_columns', None)
import math
from functools import lru_cache

from os.path import exists, isfile, join
import matplotlib.pyplot as plt
from PIL import Image
import spacy
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GroupShuffleSplit
from nltk.corpus import stopwords
import torchvision.models as models
import torch.nn as nn
from torchvision import transforms
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from keras import regularizers
from tensorflow.keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from torch.utils.data import Dataset, DataLoader
from math import ceil
import os

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %% [markdown]
# Для получения повторяемых результатов, зафиксируем состояния герераторов случайных чисел

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# ## Загрузка и исследовательский анализ данных

# %%
if exists("D:/1pr/to_upload"):
    data_path = "D:/1pr/to_upload"
else:
    data_path = "/datasets/image_search"

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Большое тебе человеческое спасибо за вынос пути к данным в отдельную константу. Это сэкономило мне немало времени при проверке.</div>

# %%
train_path = join(data_path, "train_images")
test_path = join(data_path, "test_images")

# %%
train_dataset = pd.read_csv(join(data_path, "train_dataset.csv"))

# %%
train_dataset
# Out:
#                           image                     query_id  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1     1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2     2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3     2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4     2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
# ...                         ...                          ...
# 5817   757046028_ff5999f91b.jpg  2061144717_5b3a1864f0.jpg#2
# 5818   799486353_f665d7b0f0.jpg  2196107384_361d73a170.jpg#2
# 5819   909808296_23c427022d.jpg  2112921744_92bf706805.jpg#2
# 5820   929679367_ff8c7df2ee.jpg  3651971126_309e6a5e22.jpg#2
# 5821   968081289_cdba83ce2e.jpg  2292406847_f366350600.jpg#2
#
#                                              query_text
# 0     A young child is wearing blue goggles and sitt...
# 1     A young child is wearing blue goggles and sitt...
# 2     A young child is wearing blue goggles and sitt...
# ...

# %%
train_dataset.describe()
# Out:
#                             image                     query_id  \
# count                        5822                         5822
# unique                       1000                          977
# top     3364151356_eecd07a23e.jpg  2600867924_cd502fc911.jpg#2
# freq                           10                           34
#
#                                                query_text
# count                                                5822
# unique                                                977
# top     Two dogs , one brown and white and one black a...
# freq                                                   34

# %% [markdown]
# Выводим изображения

# %%
count = 1
fig = plt.figure(figsize=(12, 12))
for _, file, query_text in train_dataset[['image','query_text']].sample(12).itertuples():
    img = Image.open(join(train_path, file))
    fig.add_subplot(3, 4, count)
    count += 1
    plt.imshow(np.array(img))
    plt.axis("off")
    chunks, chunk_size = len(query_text), 26
    plt.title("\n".join([query_text[i : i + chunk_size] for i in range(0, chunks, chunk_size)]));

# %% [markdown]
# переименовываем столбец

# %%
train_dataset = train_dataset.rename(columns={"query_id": "annotation_id"})

# %% [markdown]
# Загружаем экспертные оценки

# %%
expert_annotations = pd.read_csv(
    join(data_path, "ExpertAnnotations.tsv"), sep="\t", header=None)

# %%
expert_annotations.columns = ["image", "annotation_id", "score_1", "score_2", "score_3"]

# %%
expert_annotations
# Out:
#                           image                annotation_id  score_1  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2        1
# 1     1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2        1
# 2     1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2        1
# 3     1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2        1
# 4     1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2        1
# ...                         ...                          ...      ...
# 5817   997722733_0cb5439472.jpg  2981702521_2459f2c1c4.jpg#2        1
# 5818   997722733_0cb5439472.jpg  2985679744_75a7102aab.jpg#2        1
# 5819   997722733_0cb5439472.jpg  3150742439_b8a352e1e0.jpg#2        1
# 5820   997722733_0cb5439472.jpg  3375070563_3c290a7991.jpg#2        1
# 5821   997722733_0cb5439472.jpg   486917990_72bd4069af.jpg#2        3
#
#       score_2  score_3
# 0           1        1
# 1           1        2
# 2           1        2
# 3           2        2
# ...

# %%
expert_annotations.describe(include='all')
# Out:
#                             image                annotation_id  score_1  \
# count                        5822                         5822 5,822.00
# unique                       1000                          977      NaN
# top     3107513635_fe8a21f148.jpg  2600867924_cd502fc911.jpg#2      NaN
# freq                           10                           34      NaN
# mean                          NaN                          NaN     1.44
# std                           NaN                          NaN     0.79
# min                           NaN                          NaN     1.00
# 25%                           NaN                          NaN     1.00
# 50%                           NaN                          NaN     1.00
# 75%                           NaN                          NaN     2.00
# max                           NaN                          NaN     4.00
#
#         score_2  score_3
# count  5,822.00 5,822.00
# unique      NaN      NaN
# ...

# %% [markdown]
# Загружаем данные краудсорсинга

# %%
crowd_annotations = pd.read_csv(
    join(data_path, "CrowdAnnotations.tsv"), sep="\t", header=None)

# %%
crowd_annotations.columns = ["image", "annotation_id", "ratio", "positive", "negative"]

# %%
crowd_annotations
# Out:
#                            image                annotation_id  ratio  \
# 0      1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2   1.00
# 1      1056338697_4f7d7ce270.jpg   114051287_dd85625a04.jpg#2   0.00
# 2      1056338697_4f7d7ce270.jpg  1427391496_ea512cbe7f.jpg#2   0.00
# 3      1056338697_4f7d7ce270.jpg  2073964624_52da3a0fc4.jpg#2   0.00
# 4      1056338697_4f7d7ce270.jpg  2083434441_a93bc6306b.jpg#2   0.00
# ...                          ...                          ...    ...
# 47825   997722733_0cb5439472.jpg   543007912_23fc735b99.jpg#2   0.00
# 47826   997722733_0cb5439472.jpg   544576742_283b65fa0d.jpg#2   0.33
# 47827   997722733_0cb5439472.jpg   872622575_ba1d3632cc.jpg#2   1.00
# 47828   997722733_0cb5439472.jpg   888425986_e4b6c12324.jpg#2   0.00
# 47829   997722733_0cb5439472.jpg   997722733_0cb5439472.jpg#2   0.67
#
#        positive  negative
# 0             3         0
# 1             0         3
# 2             0         3
# 3             0         3
# ...

# %%
crowd_annotations.describe(include='all')
# Out:
#                             image               annotation_id     ratio  \
# count                       47830                       47830 47,830.00
# unique                       1000                        1000       NaN
# top     1572532018_64c030c974.jpg  249394748_2e4acfbbb5.jpg#2       NaN
# freq                          120                         169       NaN
# mean                          NaN                         NaN      0.07
# std                           NaN                         NaN      0.21
# min                           NaN                         NaN      0.00
# 25%                           NaN                         NaN      0.00
# 50%                           NaN                         NaN      0.00
# 75%                           NaN                         NaN      0.00
# max                           NaN                         NaN      1.00
#
#         positive  negative
# count  47,830.00 47,830.00
# unique       NaN       NaN
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Что еще можно было бы сделать. У нас есть два источника оценок - эксперты и краудсорс. Причем в краудсорсе оценок пара/изображение почти в 9 раз больше.  Почему бы не использовать их тоже? Данные представляют большую ценность и просто так терять их очень обидно.
#
# А сейчас ты испольовал только экспертные оценки, уточнив их краудсорсными.
# </div>

# %%
expert_annotations.head()
# Out:
#                        image                annotation_id  score_1  score_2  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2        1        1
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2        1        1
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2        1        1
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2        1        2
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2        1        1
#
#    score_3
# 0        1
# 1        2
# 2        2
# 3        2
# 4        2

# %% [markdown]
# Загружаем тестовые данные

# %%
test_queries = pd.read_csv(join(data_path, "test_queries.csv"), sep="|", index_col=0)

# %%
test_queries.head()
# Out:
#                       query_id  \
# 0  1177994172_10d143cb8d.jpg#0
# 1  1177994172_10d143cb8d.jpg#1
# 2  1177994172_10d143cb8d.jpg#2
# 3  1177994172_10d143cb8d.jpg#3
# 4  1177994172_10d143cb8d.jpg#4
#
#                                           query_text  \
# 0  Two blonde boys , one in a camouflage shirt an...
# 1  Two boys are squirting water guns at each other .
# 2            Two boys spraying each other with water
# 3  Two children wearing jeans squirt water at eac...
# 4  Two young boys are squirting water at each oth...
#
#                        image
# 0  1177994172_10d143cb8d.jpg
# 1  1177994172_10d143cb8d.jpg
# 2  1177994172_10d143cb8d.jpg
# 3  1177994172_10d143cb8d.jpg
# 4  1177994172_10d143cb8d.jpg

# %%
test_queries.describe()
# Out:
#                            query_id  \
# count                           500
# unique                          500
# top     1177994172_10d143cb8d.jpg#0
# freq                              1
#
#                                                query_text  \
# count                                                 500
# unique                                                500
# top     Two blonde boys , one in a camouflage shirt an...
# freq                                                    1
#
#                             image
# count                         500
# unique                        100
# top     1177994172_10d143cb8d.jpg
# freq                            5

# %%
test_images = pd.read_csv(join(data_path, "test_images.csv"))

# %%
test_images.head()
# Out:
#                        image
# 0  3356748019_2251399314.jpg
# 1  2887171449_f54a2b9f39.jpg
# 2  3089107423_81a24eaf18.jpg
# 3  1429546659_44cb09cbe2.jpg
# 4  1177994172_10d143cb8d.jpg

# %%
test_images.describe()
# Out:
#                             image
# count                         100
# unique                        100
# top     3356748019_2251399314.jpg
# freq                            1

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Если в следующих ячейках ты начинаешь манипулировать данными, знаит ты закончил EDA. Но мне кажется того, что ты сделал явно недостаточно. К тому же ты совсем забыл про выводы, а это наверное саммое главное.
#
#  Попробую сформулировать вопросы, ответить на которые будет интересно:
#
#   - Количество уникальных изображений в обучающем и тестовом наборах
#   - Количество уникальных запросов
#   - Количество оценок в экспертном и краудсорсинговом наборах.
#   - Что представляют из себя экспертные оценки, что представляют из себя краудсорсинговые оценки
#
#
# Выводы о том, с какими данными мы продолжим работу.
#
#
# Также рекомендую обратить внимание на то, как создана annotation_id. Можно также исследовать насколько соответствуют друг другу описания и изображения в обучающем и тестовом наборах (в разрезе соответствия друг другу annotation_id и image .
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Добавил описание в выводы.
# </div>

# %% [markdown]
# ### Вывод
#
# 1. В тренировочном датасете имеются 5822 пары изображение-описание. Уникальных изображений в тренировочном датасете 1000. Уникальных запросов 977.
# 2. В тестовом датасете 500 пар изображение-описание. Уникальных изображений 100. Уникальных запросов 500.
# 3. Количество оценок экспертов соответствует количеству пар в тренировочном датасете и составляет 5822. Средние оценки экспертов примерно равны и составляют 0.79, 0.86, 0.9.
# 4. В краудсорсинге основным показателем является "ratio" - Доля людей, подтвердивших, что описание соответствует изображению. Количество оценок полученных с помощью краудсорсинга составляет 47830. Средняя оценка доли соответствия составляет 0.21.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# объединяем мнения экспертов и доли соответствия текста изображению.

# %%
crowd_annotations
# Out:
#                            image                annotation_id  ratio  \
# 0      1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2   1.00
# 1      1056338697_4f7d7ce270.jpg   114051287_dd85625a04.jpg#2   0.00
# 2      1056338697_4f7d7ce270.jpg  1427391496_ea512cbe7f.jpg#2   0.00
# 3      1056338697_4f7d7ce270.jpg  2073964624_52da3a0fc4.jpg#2   0.00
# 4      1056338697_4f7d7ce270.jpg  2083434441_a93bc6306b.jpg#2   0.00
# ...                          ...                          ...    ...
# 47825   997722733_0cb5439472.jpg   543007912_23fc735b99.jpg#2   0.00
# 47826   997722733_0cb5439472.jpg   544576742_283b65fa0d.jpg#2   0.33
# 47827   997722733_0cb5439472.jpg   872622575_ba1d3632cc.jpg#2   1.00
# 47828   997722733_0cb5439472.jpg   888425986_e4b6c12324.jpg#2   0.00
# 47829   997722733_0cb5439472.jpg   997722733_0cb5439472.jpg#2   0.67
#
#        positive  negative
# 0             3         0
# 1             0         3
# 2             0         3
# 3             0         3
# ...

# %%
expert_annotations = expert_annotations.merge(
    crowd_annotations[["image", "annotation_id", "ratio"]],
    on=["image", "annotation_id"], how="left")

# %%
expert_annotations
# Out:
#                           image                annotation_id  score_1  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2        1
# 1     1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2        1
# 2     1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2        1
# 3     1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2        1
# 4     1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2        1
# ...                         ...                          ...      ...
# 5817   997722733_0cb5439472.jpg  2981702521_2459f2c1c4.jpg#2        1
# 5818   997722733_0cb5439472.jpg  2985679744_75a7102aab.jpg#2        1
# 5819   997722733_0cb5439472.jpg  3150742439_b8a352e1e0.jpg#2        1
# 5820   997722733_0cb5439472.jpg  3375070563_3c290a7991.jpg#2        1
# 5821   997722733_0cb5439472.jpg   486917990_72bd4069af.jpg#2        3
#
#       score_2  score_3  ratio
# 0           1        1   0.00
# 1           1        2   0.00
# 2           1        2    NaN
# ...

# %%
#expert_annotations['ratio'] = expert_annotations['ratio'].fillna(0)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# А вот здесь ошибка в логике. Смотри, возмжоны две ситуации:
#
#  - есть только экспертные оценки. и здесь нужно использоватьт их  (предварительно приведя в диапазон 0-1)
#  - а если есть и те и другие - используем взвешенную сумма
#
#
# А сейчас ты заполняешь нулями, соответственно там, где нет одной из оценок будут сильно смещены вниз. nan это отсутствие оценки, а не оценка 0
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Убрал заполнение пропусков нулями. Действительно сглупил.
# </div>

# %% [markdown]
# ### Построение сводной экспертной оценки

# %%
def comparison(a1, a2, a3, b1):
    """функция принимает оценки экспертов и долю людей, подтвердивших, 
    что описание соответствует изображению и возвращает рейтинг соответствия. 
    Если данные о доле соответсвия отсутствует в данных то рейтинг считается только по оценкам экспертов"""
    if math.isnan(b1):
        return round(0.25 * np.mean([a1,a2,a3]), 2)
    else: 
        return round(0.15 * np.mean([a1,a2,a3]) + 0.4 * b1, 2)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Получилась очень сложная функция с неочевидной логикой. Здесь однозначно нужно тектовое описание. А еще лучше рефакторинг.
#
# К тому же она очень странно обрабатывает ситуацию, когда две экспепертных оценки одинаковые, а третья отличается от них. Ты берешь не самую популярную оценку, а вычисляешь среднее. А если так, то зачем вообще усложнять и почему бы не взять просто среднее?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Исправил функцию. Добавил описание.
# </div>

# %%
expert_annotations["experts"] = expert_annotations.apply(    
    lambda x: comparison(x["score_1"], x["score_2"], x["score_3"], x["ratio"] ), axis=1)

# %% [markdown]
# Сохраняем только рейтинг соответствия только который больше 0,1

# %%
data_expert_annotations = expert_annotations[
    ['image', 'annotation_id','experts']][expert_annotations['experts'] > 0.1].copy()

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Старайся не делать такие длинные строки. Стандарт PEP8 регулирует длину строки 79 символов. Придерживаться такого очень сложно, но лучше хотя-бы вмещать в экран, чтобы не приходилось использовать scroll.
#
#
# А еще  если сомневаешься, как отформатировать правильно - всегда можно найти какой-нибудь оналйн-форматтер, например этот
#
#   https://extendsclass.com/python-formatter.html
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Исправил.
# </div>

# %% [markdown]
# Смотрим уникальные значения полученных рейтингов.

# %%
data_expert_annotations['experts'].unique()
# Out:
# array([0.15, 0.2 , 0.33, 0.42, 0.25, 0.5 , 0.3 , 0.53, 0.58, 0.4 , 0.48,
#        0.45, 0.67, 0.87, 0.75, 0.95, 1.  , 0.85, 0.62, 0.43, 0.35, 0.83,
#        0.9 , 0.72, 0.38, 0.63, 0.77, 0.57, 0.73, 0.92, 0.68, 0.82, 0.7 ,
#        0.8 , 0.61, 0.52, 0.65, 0.55, 0.28])

# %%
data_expert_annotations.head()
# Out:
#                        image                annotation_id  experts
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2     0.15
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2     0.20
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2     0.33
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2     0.42
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2     0.33

# %% [markdown]
# Проставляем рейтинги для тренировочных данных

# %%
df = (
    train_dataset.set_index(["image", "annotation_id"])
    .join(
        data_expert_annotations.set_index(["image", "annotation_id"])[["experts"]],
        how="inner",
    )
    .reset_index()
).copy()

# %%
df
# Out:
#                           image                annotation_id  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1     1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2     2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3     2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4     2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
# ...                         ...                          ...
# 5817   757046028_ff5999f91b.jpg  2061144717_5b3a1864f0.jpg#2
# 5818   799486353_f665d7b0f0.jpg  2196107384_361d73a170.jpg#2
# 5819   909808296_23c427022d.jpg  2112921744_92bf706805.jpg#2
# 5820   929679367_ff8c7df2ee.jpg  3651971126_309e6a5e22.jpg#2
# 5821   968081289_cdba83ce2e.jpg  2292406847_f366350600.jpg#2
#
#                                              query_text  experts
# 0     A young child is wearing blue goggles and sitt...     0.15
# 1     A young child is wearing blue goggles and sitt...     0.25
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# ОК, краудсорс и экспертные оценки объеденены.</div>

# %% [markdown]
# ### Лемматизация описаний

# %%
#spacy.cli.download("en_core_web_lg")
nlp = spacy.load("en_core_web_lg", disable=['parser', 'ner'])

# %%
def lemmatizered(corpus):
    ''' функция выполняет токенизациию и лемматизацию массива текстов'''
    corpus_new = []
    for sentence in corpus:
        sentence = sentence.replace('  ', ' ')
        doc = nlp(sentence)      
        corpus_new.append(" ".join([token.lemma_ for token in doc]))
    return corpus_new

# %%
# %%time
pattern = r'[^a-zA-Z0-9]'
df['clear_text'] = df['query_text'].apply(lambda x: re.sub(pattern, " ", x))
df['clear_text'] = lemmatizered(df['clear_text'])
df.head()
# Out:
# Wall time: 8.08 s
#                        image                annotation_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text  experts  \
# 0  A young child is wearing blue goggles and sitt...     0.15
# 1  A young child is wearing blue goggles and sitt...     0.25
# 2  A young child is wearing blue goggles and sitt...     0.25
# 3  A young child is wearing blue goggles and sitt...     1.00
# 4  A young child is wearing blue goggles and sitt...     0.25
#
#                                           clear_text
# 0  a young child be wear blue goggle and sit in a...
# 1  a young child be wear blue goggle and sit in a...
# 2  a young child be wear blue goggle and sit in a...
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Тут все ОК, текст лемматизирован. Молодец, что используешь spaCy</div>

# %% [markdown]
# ### Удаление проблемного контента

# %% [markdown]
# Прежде всего, составим список слов, используемых в английском для обозначения детей и подростков и напишем функцию, которая будет искать эти слова в лемматезированных текстах

# %%
stop = [
    "boy",
    "girl",
    "child",
    "baby",
    "kid",
    "babe",
    "infant",
    "teenager",
    "teeny",
    "juvenile",
    "teener",
    "stripling",
]

# %%
def stop_in_text(text: str) -> bool:
    """Последовательно ищем слова из стоп-листа child_stop в заданном тексте text. 
    Возвращаем True, если нашлось хотя бы одно слово"""
    sign = False
    for w in stop:
        sign |= text.lower().find(w) > -1
    return sign

# %%
df["clear_text_stop"] = df.apply(
    lambda x: stop_in_text(x["clear_text"]), axis=1
)

# %% [markdown]
# Удаляем изображения со стопсловами. Предварительно отсортируем изображения, в описании к которым содержатся стопслова и рейтинг соответствия более 0,3.

# %%
text_stop = set(df[(df["clear_text_stop"] == True) & (df["experts"] > 0.3)]["image"])

# %% [markdown]
# Удаляем все записи, содержащие эти изображения.

# %%
df = df.drop(df[df["image"].isin(text_stop)].index, axis=0)

# %%
df.shape
# Out:
# (3427, 6)

# %% [markdown]
# Тренировочный датасет уменьшился на 2395 пар изображение-описание.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# По условиям проекта, нужно почистить датасет от данных, на которые могут распространяться юридические ограничения.
# Для этого нужно:
#
#    - Создать список слов которые, могут попадать под юридические ограничения.
#    -  Исключить из обучающего датасета пары, которые, исходя из данного списка слов, могут попадать под юридические ограничения.
#
#
# Также я бы посоветовал тебе не торопиться исключать все пары изображение/запрос, если в запросе присутствуют слова, связанные с детьми. Ведь некоторые пары помечены как "изображение и запрос совершенно не соответствуют друг другу". Значит при исключении из рассмотрения "плохих" изображений нужно учесть проставленные оценки.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Добавил исключение проблемного контента.
# </div>

# %% [markdown]
# ### Разбиение тренировочного множества на тренировочную и валидационную выборки

# %%
gss = GroupShuffleSplit(n_splits=1, train_size=0.75, random_state=42)
train_indices, valid_indices = next(
    gss.split(
        X=df.drop(columns=["annotation_id"]),
        y=df["annotation_id"],
        groups=df["image"],
    )
)
train_df, valid_df = df.iloc[train_indices], df.iloc[valid_indices]

# %%
train_df.head()
# Out:
#                         image                annotation_id  \
# 0   1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 6   3155451946_c0862c70cb.jpg  2549968784_39bfbe44f9.jpg#2
# 7   3222041930_f642f49d28.jpg  2549968784_39bfbe44f9.jpg#2
# 11   486712504_36be449055.jpg  2549968784_39bfbe44f9.jpg#2
# 12  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2
#
#                                            query_text  experts  \
# 0   A young child is wearing blue goggles and sitt...     0.15
# 6   A young child is wearing blue goggles and sitt...     0.25
# 7   A young child is wearing blue goggles and sitt...     0.25
# 11  A young child is wearing blue goggles and sitt...     0.25
# 12  A girl wearing a yellow shirt and sunglasses s...     0.20
#
#                                            clear_text  clear_text_stop
# 0   a young child be wear blue goggle and sit in a...             True
# 6   a young child be wear blue goggle and sit in a...             True
# ...

# %%
valid_df.head()
# Out:
#                         image                annotation_id  \
# 18  3503689049_63212220be.jpg  2718495608_d8533e3ac5.jpg#2
# 33  2101457132_69c950bc45.jpg  3286822339_5535af6b93.jpg#2
# 35  3100251515_c68027cc22.jpg  3286822339_5535af6b93.jpg#2
# 36   370614351_98b8a166b9.jpg  3286822339_5535af6b93.jpg#2
# 60   114051287_dd85625a04.jpg   434792818_56375e203f.jpg#2
#
#                                            query_text  experts  \
# 18  A girl wearing a yellow shirt and sunglasses s...     0.30
# 33         Chinese market street in the winter time .     0.15
# 35         Chinese market street in the winter time .     0.25
# 36         Chinese market street in the winter time .     0.25
# 60  A man and woman look back at the camera while ...     0.25
#
#                                            clear_text  clear_text_stop
# 18      a girl wear a yellow shirt and sunglass smile             True
# 33           chinese market street in the winter time            False
# ...

# %% [markdown]
# ### Векторизация описаний

# %%
#import nltk
#nltk.download()

# %%
stop_words = set(stopwords.words("english"))

# %%
tfvect = TfidfVectorizer(stop_words=stop_words)

# %% [markdown]
# Векторизируем текст

# %%
train_tf_text = tfvect.fit_transform(train_df["clear_text"])
valid_tf_text = tfvect.transform(valid_df["clear_text"])

# %%
train_tf_text = train_tf_text.toarray()
train_tf_text.shape
# Out:
# (2554, 1061)

# %%
valid_tf_text = valid_tf_text.toarray()
valid_tf_text.shape
# Out:
# (873, 1061)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 Вектора для текста получены с помощью TF-IDF. И полодец, что разбил данные на выборки и обучил векторайзер на обучающей выборке и применил его к валидационной.</div>

# %% [markdown]
# ### Векторизация изображений

# %% [markdown]
# Загрузим модель ResNet-18:

# %%
resnet = models.resnet18(pretrained=True) #загружаем претренированную модель

# %% [markdown]
# Нам не потребуется обучать модель, поэтому рекомендуем заморозить веса:

# %%
for param in resnet.parameters():
    param.requires_grad_(False)

# %% [markdown]
# После заморозки весов надо определиться, все ли слои можно использовать для получения эмбеддингов. На практике используются только свёрточные слои. Для получения списка слоёв пригодится метод children():

# %%
print(list(resnet.children()))
# Out:
# [Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False), BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True), ReLU(inplace=True), MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False), Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
# ...

# %% [markdown]
# В нашем случае, нужно взять все слои, кроме одного последнего:

# %%
modules = list(resnet.children())[:-1]

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Ты прав,  лучше взять все кроме одного последнего. В этом случае размер вектора получается более адекватный - всего 512 )) </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Только исправь пожалуйста текстовый комментарий.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Исправил.
# </div>

# %%
resnet = nn.Sequential(*modules)

# %% [markdown]
# Не забудем перевести модель в режим предсказания:

# %%
resnet.eval()
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# Теперь перейдём к тому, как получить предсказания. Для начала изображение нужно привести в нужный формат. Для изменяют размер картинки, вырезают центр и нормализуют:

# %%
norm = transforms.Normalize(
    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    norm,
])

# %% [markdown]
# Данные преобразования применимы к модели ResNet. Для других моделей уточняйте необходимые преобразования в документации.
# Для чтения изображений понадобится библиотека PIL:

# %%
@lru_cache(maxsize=128, typed=False)
def vec_im(image, path):
    ''' функция принимает на вход имя изображения и адрес папки с изображением 
    на выходе выполняет векторизацию изображения '''
    return resnet(
        preprocess(
            Image.open(join(path, image)).convert('RGB')).unsqueeze(0)).flatten()

# %%
# %%time
train_img = train_df.apply(lambda x: vec_im(x["image"], train_path), axis=1)
# Out:
# Wall time: 37.3 s

# %%
# %%time
valid_img = valid_df.apply(lambda x: vec_im(x["image"], train_path), axis=1)
# Out:
# Wall time: 4.8 s

# %%
# %%time
test_img = test_images.apply(lambda x: vec_im(x["image"], test_path), axis=1)
# Out:
# Wall time: 2.13 s

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Если подходить формально - то изображения ты векторизовал. Но операция векторизации изображения дорогая. А ты векторизовал многие изображения по нескольку раз (количество уникальных изображений гораздо больше, чем пар изображение/текст). Было бы оптимальнее отдельно векторизовать изображения (все уникальные), а затем добавить ту информацию к нашим данным.
#
# Хотя возможно это повод познакомиться с полезным декоратором @lru_cash.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Офигенная штука @lru_cash, время в разы сокращает. Спасибо большое за подсказку!
# </div>

# %%
image_vecs = []
for tensor in train_img.to_numpy():
    image_vecs.append(list(tensor.numpy()))
train_tf_img = np.array(image_vecs)
train_tf_img.shape
# Out:
# (2554, 512)

# %%
image_vecs = []
for tensor in valid_img.to_numpy():
    image_vecs.append(list(tensor.numpy()))
valid_tf_img = np.array(image_vecs)
valid_tf_img.shape
# Out:
# (873, 512)

# %%
image_vecs = []
for tensor in test_img.to_numpy():
    image_vecs.append(list(tensor.numpy()))
test_tf_img = np.array(image_vecs)
test_tf_img.shape
# Out:
# (100, 512)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Отлично, вектра для изображений получены👍 </div>

# %% [markdown]
# Тогда получение эмбеддинга для конкретной картинки будет выглядеть так:

# %%
df_train = np.concatenate((train_tf_img, train_tf_text), axis=1)
df_train.shape
# Out:
# (2554, 1573)

# %%
df_valid = np.concatenate((valid_tf_img, valid_tf_text), axis=1)
df_valid.shape
# Out:
# (873, 1573)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Вектора, полученные из текста и изображения объеденены👍 </div>

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Готовим данные для обучения

# %%
X_train = df_train.copy() 
Y_train = train_df['experts'].reset_index(drop=True)

# %%
X_valid = df_valid.copy() 
Y_valid = valid_df['experts'].reset_index(drop=True)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# ### Линейная регрессия

# %% [markdown]
# Для определения качества моделей выбираем метрику RMSE. Чем меньше значение RMSE тем лучше. Данная метрика хорошо подходит для задачи регрессии в которой отсутствуют выбросы.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# В этом задании требуется выбрать основную метрику, которую ты будешь оптимизировать. Судя по коду ты уже выбрал метрику mse. Остается написать обоснование для своего выбора.  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Изменил метрику на RMSE. Обоснование написал.
# </div>

# %%
model = LinearRegression().fit(X_train, Y_train)

# %%
predicted_valid = model.predict(X_valid)

# %%
math.sqrt(mean_squared_error(Y_valid, predicted_valid))
# Out:
# 1055727485162.3011

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Линейная регрессия обучена. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> С измененными данными линейная регрессия обучается криво.
# </div>

# %% [markdown]
# Линейная регрессия обучается неправильно. Метрика сильно завышена.

# %% [markdown]
# ### Нейронная сеть pytorch

# %%
vector_size = X_train.shape[1]
vector_size
# Out:
# 1573

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# В этом раздеел есть проблема и заключается она в следующем. Для векторизации изображений ты использовал resnet18, основанный на Pytorch.  А нейронку для предсказания соответствия решил собрать на Keras.  Поддержка двух DL фреймворков - это будет ад для девопса. Поэтому хорошей практикой является использование одного фреймворка в одном проекте. Советую переписать эту нейроку на pytorch, можешь использовать нотацию nn.Sequentional, с ней простые последовательные модели собираются быстрее.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Написал модель неросети на pytorch и добавил EarlyStopping чтобы не дать модели переобучиться. Модель нейросети на Keras оставил в качестве примера. Всё-таки это тоже опыт и практика, не хотелось бы удалять её из проекта. Но совет я услышал, спасибо большое!
# </div>

# %%
class Model_improve(nn.Module):
    def __init__(self, n_in_neurons, n_hidden_neurons_1, n_hidden_neurons_2, n_out_neurons, 
                 dropout_1, dropout_2, activation_1, activation_2):
        super(Model_improve, self).__init__()
        
        self.fc1 = nn.Linear(n_in_neurons, n_hidden_neurons_1)        
        self.bn1 = nn.BatchNorm1d(n_hidden_neurons_1)
        self.dp1 = nn.Dropout(p=dropout_1)
        self.act1 = activation_1
        
        self.fc2 = nn.Linear(n_hidden_neurons_1, n_hidden_neurons_2)
        self.bn2 = nn.BatchNorm1d(n_hidden_neurons_2) 
        self.dp2 = nn.Dropout(p=dropout_2)
        self.act2 = activation_2    
     
        self.fc3 = nn.Linear(n_hidden_neurons_2, n_out_neurons)
        self.act3 = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x)
        x = self.bn1(x)
        x = self.dp1(x)
        x = self.act1(x)

        x = self.fc2(x)
        x = self.bn2(x)
        x = self.dp2(x)
        x = self.act2(x)
       
        x = self.fc3(x)
        x = self.act3(x)
        
        return x

# %%
net = Model_improve(n_in_neurons=vector_size, 
                    n_hidden_neurons_1=64, 
                    n_hidden_neurons_2=32, 
                    n_out_neurons=1, 
                    dropout_1=0.1, 
                    dropout_2=0.1, 
                    activation_1=nn.LeakyReLU(), 
                    activation_2=nn.LeakyReLU())

# %%
class CustomEarlyStopping():
    """
    Ранняя остановка, чтобы остановить тренировку, когда потеря не улучшается после определенной эпохи.
    """
    def __init__(self, patience=5, min_delta=0):
        """
        :param patience: сколько эпох ждать, прежде чем остановиться, когда потеря не улучшается
        :param min_delta: минимальная разница между loss/метриками, если улучшений нет, то остановим обучение
        """
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss == None:
            self.best_loss = val_loss
        elif self.best_loss - val_loss > self.min_delta:
            self.best_loss = val_loss
            # reset counter if validation loss improves
            self.counter = 0
        elif self.best_loss - val_loss < self.min_delta:
            self.counter += 1
            print(f"INFO: Early stopping counter {self.counter} of {self.patience}")
            if self.counter >= self.patience:
                print('INFO: Early stopping')
                self.early_stop = True
                
                

print(net)
def init_weights(m):
        if isinstance(m, nn.Linear):
            torch.nn.init.kaiming_normal_(m.weight)
            m.bias.data.fill_(0.01)
            
            
net.apply(init_weights)
print(net)


loss = nn.MSELoss()
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)

num_epochs = 1000 #ставим какое нибудь большое число, все равно до него не дойдем из за EarlyStopping


early_stopping = CustomEarlyStopping(patience=3, min_delta=0.002) #Эти параметры можно подбирать
# Out:
# Model_improve(
#   (fc1): Linear(in_features=1573, out_features=64, bias=True)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dp1): Dropout(p=0.1, inplace=False)
#   (act1): LeakyReLU(negative_slope=0.01)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dp2): Dropout(p=0.1, inplace=False)
#   (act2): LeakyReLU(negative_slope=0.01)
#   (fc3): Linear(in_features=32, out_features=1, bias=True)
#   (act3): ReLU()
# )
# Model_improve(
#   (fc1): Linear(in_features=1573, out_features=64, bias=True)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dp1): Dropout(p=0.1, inplace=False)
#   (act1): LeakyReLU(negative_slope=0.01)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (bn2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
dataset_train = torch.utils.data.TensorDataset(
    torch.FloatTensor(X_train), 
    torch.FloatTensor(Y_train)
)
dataset_valid = torch.utils.data.TensorDataset(
    torch.FloatTensor(X_valid), 
    torch.FloatTensor(Y_valid)
)

train_dataloader = DataLoader(dataset_train, 
                              batch_size=32, 
                              shuffle=True,
                              num_workers=0
                             )
valid_dataloader = DataLoader(dataset_valid, 
                             batch_size=32, 
                             num_workers=0
                            )

# %%
for epoch in range(num_epochs):
    net.train()
    for batch in train_dataloader:
        x_train, y_train = batch 
        optimizer.zero_grad()
        
        preds = net.forward(x_train).flatten()
               
        loss_value = torch.sqrt(loss(preds, y_train))
        loss_value.backward()
        optimizer.step()
        
    if epoch % 5 == 0:
        predicted_temp = [] 
        with torch.no_grad():
            net.eval()
            for batch in valid_dataloader:
                x_valid, y_valid = batch                
                
                valid_preds = net.forward(x_valid).flatten()
                predicted_temp.append(valid_preds)
                RMSE_loss = torch.sqrt(loss(valid_preds, y_valid))
                
        predicted_temp = torch.cat(predicted_temp).detach().numpy()
        RMSE = mean_squared_error(torch.FloatTensor(Y_valid), predicted_temp, squared=False)
        early_stopping(RMSE)
        print(f"epoch:{epoch}, RMSE test: {RMSE}")
        
        if early_stopping.early_stop:
            print('Early Stoppning!!!')
            break
# Out:
# epoch:0, RMSE test: 0.37788450717926025
# epoch:5, RMSE test: 0.28825515508651733
# epoch:10, RMSE test: 0.202360138297081
# INFO: Early stopping counter 1 of 3
# epoch:15, RMSE test: 0.2135114073753357
# epoch:20, RMSE test: 0.19349975883960724
# epoch:25, RMSE test: 0.18897850811481476
# epoch:30, RMSE test: 0.1860456019639969
# epoch:35, RMSE test: 0.18161797523498535
# INFO: Early stopping counter 1 of 3
# epoch:40, RMSE test: 0.1871301680803299
# INFO: Early stopping counter 2 of 3
# epoch:45, RMSE test: 0.18878072500228882
# INFO: Early stopping counter 3 of 3
# INFO: Early stopping
# epoch:50, RMSE test: 0.18868158757686615
# Early Stoppning!!!

# %% [markdown]
# Качество обученной модели нейросети pytorch на валидационной выборке составила 0,18

# %% [markdown]
# ### Нейронная сеть Keras

# %%
def create_nn_model():
    optimizer = Adam()
    model = Sequential()    
    model.add(Dense(units = 128, 
                    kernel_initializer = "uniform", 
                    activation = "relu", 
                    input_dim = vector_size,
                    activity_regularizer = regularizers.l2(0.001)))
    #model.add(BatchNormalization(axis=1))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 128, 
                    kernel_initializer = "uniform", 
                    activation = "relu"))
    #model.add(BatchNormalization(axis=1))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 1, 
                    kernel_initializer = "uniform", 
                    activation = "relu"))
    model.compile(optimizer=optimizer, 
                  loss=tf.keras.metrics.mean_squared_error, 
                  metrics=[tf.keras.metrics.RootMeanSquaredError(name='rmse')])

    return model

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Действительно, модель не учится. Если нейронки не учатся, можно попробовать несколько стратегий
#
#  - Сделать модель посложнее, увеличив количество слоев / нейронов в слое
#  - Уменьшить регуляризацию. Всетаки каждый раз выкидывать 50% связей это слишком. Попробуй вначале вообще убрать дропаут, возмжоно заменить его на слой батч-нормализации.  И только если будет сильное переобучение можно будет по немногу его возвращать
#
#  - Ну и стандартный рецепт - если вышли на плато, уменьшам шаг обучения.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Исправил модель, не стал убирать Dropout, без него модель очень быстро переобучается. Сейчас модель бодрее обучается, хотя бы не статичные показатели.
# </div>

# %%
nn_model = create_nn_model()

# %%
history = nn_model.fit(
    X_train,
    Y_train,
    batch_size=32,
    epochs=20,
    validation_data=(X_valid, Y_valid),
)
# Out:
# Epoch 1/20
# 80/80 [==============================] - 1s 4ms/step - loss: 0.0592 - rmse: 0.2201 - val_loss: 0.0423 - val_rmse: 0.1964
# Epoch 2/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0427 - rmse: 0.1992 - val_loss: 0.0429 - val_rmse: 0.2001
# Epoch 3/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0374 - rmse: 0.1894 - val_loss: 0.0391 - val_rmse: 0.1963
# Epoch 4/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0347 - rmse: 0.1840 - val_loss: 0.0379 - val_rmse: 0.1922
# Epoch 5/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0339 - rmse: 0.1817 - val_loss: 0.0372 - val_rmse: 0.1908
# Epoch 6/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0349 - rmse: 0.1849 - val_loss: 0.0366 - val_rmse: 0.1904
# Epoch 7/20
# 80/80 [==============================] - 0s 2ms/step - loss: 0.0337 - rmse: 0.1818 - val_loss: 0.0377 - val_rmse: 0.1930
# Epoch 8/20
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Модели Keras отлично работают с numpy объектами, совсем не обязательно переводить данные в тензоры, как для чистого tf.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Исправил, спасибо за подсказку.
# </div>

# %% [markdown]
# Качество обученной модели нейросети Keras на валидационной выборке составила 0,19

# %% [markdown]
# ## Тестирование модели

# %%
indexes = np.random.randint(0, 499, size=1)
queries = test_queries.loc[indexes, 'query_text'].values

# %%
def image_search(text, test_img_vec, model, test_images_name):
    '''Принимает на вход текстовое описание, делает его векторизацию
    и возвращает картинку с максимальным значением метрики'''
    for word in stop:
        if word in text:
            return 'This image is unavailable in your country in compliance with local laws'
        
    text_lem = []
    for x in range(len(queries)):
        text_lem.append(re.sub(pattern, " ", queries[x]))
    text_lem = np.array(text_lem, dtype=object)
    text_lem = lemmatizered(text_lem)
    text_test_vec = tfvect.transform(text_lem)
    text_test_vec = text_test_vec.toarray()
    
    for n in range(7):
        text_test_vec = np.concatenate((text_test_vec, text_test_vec))
    text_test_vec = text_test_vec[0:100]
    X = np.concatenate((test_img_vec, text_test_vec), axis=1)  
    preds_val = model.predict(X).flatten()
    idx = np.argsort(preds_val)[-3:]
    name = test_images_name.loc[idx, 'image']
    return name

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Небольшая формальность - пожалуйста добавь в код функции инфереса, чтобы она кроме изображения и текста  выводила найденную меру близости.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Меру добавил только у нейросети pytorch. Так как результаты интересны только у данной модели как наиболее эффективной.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Несколько замечаний по функции. Во первых, пока не запустишь код и не посмотришь содержимое переменых совершенно непонятно как она работает. Две переменных test_img и  test_images.  Очень непросто догадаться что в первой вектора, а во второй названия.  Нужно подбирать корректные названия.
#
# Также я вижу "кашу" их torch и tf.  Одновременно ты и на DEVICE отправляешь и в тензоры кастуешь... Все это нужно убирать и оставаться в рамках одного фреймворка.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента: </b> Переименовал переменные и убрал лишние действия.
# </div>

# %% [markdown]
# Тестируем модель линейной регрессии

# %%
count = 1
print(queries[0])
fig = plt.figure(figsize=(12, 12))
for x in image_search(queries, test_tf_img, model, test_images):    
    img = Image.open(join(test_path, x))
    fig.add_subplot(1, 3, count)
    count += 1
    plt.imshow(np.array(img))
    plt.axis("off")
# Out:
# A young boy throwing a rock into a pond in front of a large building .

# %% [markdown]
# Тестируем модель нейросети Keras

# %%
count = 1
print(queries[0])
fig = plt.figure(figsize=(12, 12))
for x in image_search(queries, test_tf_img, nn_model, test_images):    
    img = Image.open(join(test_path, x))
    fig.add_subplot(1, 3, count)
    count += 1
    plt.imshow(np.array(img))
    plt.axis("off")
# Out:
# A young boy throwing a rock into a pond in front of a large building .
# 4/4 [==============================] - 0s 1ms/step

# %%
def image_search_pytorch(text, test_img_vec, model, test_images_name):
    '''Принимает на вход текстовое описание, делает его векторизацию
    и возвращает картинку с максимальным значением метрики'''
    for word in stop:
        if word in text:
            return 'This image is unavailable in your country in compliance with local laws'
        
    text_lem = []
    for x in range(len(queries)):
        text_lem.append(re.sub(pattern, " ", queries[x]))
    text_lem = np.array(text_lem, dtype=object)
    text_lem = lemmatizered(text_lem)
    text_test_vec = tfvect.transform(text_lem)
    text_test_vec = text_test_vec.toarray()
    
    for n in range(7):
        text_test_vec = np.concatenate((text_test_vec, text_test_vec))
    text_test_vec = text_test_vec[0:100]
    X = np.concatenate((test_img_vec, text_test_vec), axis=1)
    model.eval()
    with torch.no_grad():
        X = torch.FloatTensor(X)        
        preds_val = net(X).flatten(start_dim=-2)        
        idx = np.argsort(preds_val)[-3:]
        preds_val = pd.DataFrame(preds_val.numpy(), columns = ['ratio'])
        name = test_images_name.loc[idx, 'image']
        ratio = preds_val.loc[idx, 'ratio']
    
   
    return name, ratio, idx

# %% [markdown]
# Тестируем модель нейросети pytorch

# %%
count = 1
print(queries[0])
name_image, ratio, idx = image_search_pytorch(queries, test_tf_img, net, test_images)
idx = idx.numpy()
fig = plt.figure(figsize=(12, 12))

for i in idx:
    img = Image.open(join(test_path, name_image[i]))
    fig.add_subplot(1, 3, count)
    count += 1
    plt.imshow(np.array(img))
    plt.axis("off")   
    plt.title(ratio[i])
# Out:
# A young boy throwing a rock into a pond in front of a large building .

# %% [markdown]
# ### Выводы
#
# Модель нейросети pytorch показала лучшее качество чем остальные.

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Идеи и альтернативные подходы</b>
#     Если хочешь получить хорошо работающее решение без обучения, то можешь провести эксперимент с нейронной сетью CLIP от OPEN AI (это не обязательно, только если хочешь добиться хороших результатов в этом проекте).
#
# Про эту нейронку много где написано, но можешь посмотреть например вот здесь  https://habr.com/ru/post/539312/.
#
# А для написания  реализации наиболее удобной лично для меня оказалась библиотека sbert. https://www.sbert.net/examples/applications/image-search/README.html
#
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
# Подведем итоги. Я вижу, что в целом с проектом ты справляешься.
#
# Получены признаки из текста и изображений, обучена модель регрессии. Нейросетевую модель можно еще немного доучить, направления поиска я тебе дал.
#
#
# Что нужно доделать обязательно:
#
#    - Нужно сделать чуть более развернутый разведочный анализ и завершить его выводами
#    - Нужно почистить датасет от детских изображений
#    - Нужно дать объяснения, почему выбрана именно метрика mae
#    - Нужно сделать так, чтобы на запрос, содержащий детскую тематику выдавался дисклеймер
#    - Ну и нужно просто завершить проек - применить функцию инференса к 10 случайыным запросам из тестовой выборки.
#
# Желтые комментарии на твое усмотрение.
#
# Это формальная сторона. Теперь по поводу качества модели. На мой вгляд здесь есть две самых больших сложности
#
#   - очень маленький размер датасета
#   - использованный подход (конкатенация векторов и предсказание соответствия). Обычно такие задачи решаются переводом векторов изображений и текстов в одно пространство и использованием меры близости, например косинусного расстояния.
#
# Также по моим наблюдениям вектора, полученные с помощью BERT дают чуть лучший результат. Также неплохо себя показала "векторизация" изображений без обрезания последнего слоя.
#
# Поэтотому я предлагаю тебе вначале закрыть формальные вопросы по проекту, а затем попробовать сделать прототип с использованием CLIP и библиотеки sbert (они просто предоставляют удобную оболочку). Сделать это достаточно просто, а результаты впечатляют.
#
#
#
#
#
#
#
# Жду твою работу на повторное ревью.
# </div>
